# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

import numpy as np
import pylab
import math

# %matplotlib inline
pylab.rcParams['figure.figsize'] = (10, 10)
import matplotlib.pyplot as plt

# %%
sess = None
def ResetSession():
    tf.reset_default_graph()
    global sess
    if sess is not None: sess.close()
    sess = tf.InteractiveSession()

# %%
ResetSession()

mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

NUM_CLASSES = 10
NUM_PIXELS = 28*28
TRAIN_STEPS = 5000
BATCH_SIZE = 100

HIDDEN1_UNITS = 512
LEARNING_RATE = 0.1

x = tf.placeholder(dtype = tf.float32, shape = [None, NUM_PIXELS], name = "pixels")
y_ = tf.placeholder(dtype = tf.float32, shape = [None, NUM_CLASSES], name = "labels")

def weight_variable(num_inputs, num_outputs, name):
    initial = tf.truncated_normal(shape = [num_inputs, num_outputs], stddev=1.0/ math.sqrt(float(num_inputs)))
    return tf.Variable(initial, name=name)

def bias_variable(shape, name):
    initial = tf.constant(0.0, shape = [shape])
    return tf.Variable(initial, name=name)

#define weights and bias terms for initial layer
weights1 = weight_variable(NUM_PIXELS, HIDDEN1_UNITS, "weights1")
biases1 = bias_variable(HIDDEN1_UNITS, "biases1")

#define predictions into first layer using rectifier linear "link" functions
hidden1 = tf.nn.relu(tf.matmul(x, weights1) + biases1, name="hidden1")

#define weights and bias terms for hidden layer into output layer
weights2 = weight_variable(HIDDEN1_UNITS, NUM_CLASSES, "weights2")
biases2 = bias_variable(NUM_CLASSES, "biases2")

#define predictions into output layer
y = tf.add(tf.matmul(hidden1, weights2), biases2)

summary_writer = tf.train.SummaryWriter("summaries/single_hidden_layer", graph=tf.get_default_graph())
summary_writer.close()

#define cost function
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(y, y_)) #y depends on x, and y_ is a placeholder for true labels
train_step = tf.train.GradientDescentOptimizer(0.5).minimize(cross_entropy)

#initialize graph
sess.run(tf.initialize_all_variables())

#training routine
for i in range(TRAIN_STEPS):
    batch_xs, batch_ys = mnist.train.next_batch(BATCH_SIZE)
    _, loss = sess.run([train_step, cross_entropy], feed_dict={x: batch_xs, y_: batch_ys})
    # train_step updates model parameters
    if i%200 == 0:
        print("loss is %f" % loss)

#define a prediction to be correct if it agrees with the label:
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))

#define accuracy by average number of correct predictions over test sample
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

#evaluate correctness of predictions averaged across all test images
print("\nAccuracy of trained model on test images is %f" % sess.run(accuracy, feed_dict = {x:mnist.test.images, y_: mnist.test.labels}))
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-9-3f6ec7cf0fed>:38 in <module>.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-9-3f6ec7cf0fed>:46 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# loss is 2.302305
# loss is 0.161721
# loss is 0.201341
# loss is 0.185893
# loss is 0.064358
# loss is 0.104824
# loss is 0.056118
# loss is 0.059488
# loss is 0.079860
# loss is 0.037278
# loss is 0.046379
# loss is 0.022636
# loss is 0.022660
# loss is 0.024213
# loss is 0.016777
# loss is 0.046433
# loss is 0.037938
# loss is 0.008680
# loss is 0.003901
# loss is 0.025421
# loss is 0.017159
# loss is 0.018320
# loss is 0.013975
# loss is 0.026688
# loss is 0.007928
#
# Accuracy of trained model is 0.982300

# %% [markdown]
# ### Exercise
#
# Add a second hidden layer to the above code, with 64 units. Experiment with the parameters (batch size, steps, learning rate, units per layer) to see if you can achieve higher accuracy than the single hidden layer model. Keep in mind there's randomness between runs.

# %%
def run(train_steps, batch_size, units1, units2, learning_rate):
    """runner function that generalizes above setup to include a second intermediate layer"""
    ResetSession()

    mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

    NUM_CLASSES = 10
    NUM_PIXELS = 28*28
    TRAIN_STEPS = train_steps
    BATCH_SIZE = batch_size

    HIDDEN1_UNITS = units1
    HIDDEN2_UNITS = units2
    LEARNING_RATE = learning_rate

    x = tf.placeholder(dtype = tf.float32, shape = [None, NUM_PIXELS], name = "pixels")
    y_ = tf.placeholder(dtype = tf.float32, shape = [None, NUM_CLASSES], name = "labels")

    def weight_variable(inputs, outputs, name):
        initial = tf.truncated_normal(shape = [inputs, outputs], stddev=1.0/ math.sqrt(float(inputs)))
        return tf.Variable(initial, name=name)

    def bias_variable(shape, name):
        initial = tf.constant(0.0, shape = [shape])
        return tf.Variable(initial, name=name)

    #parameters and predictions from input layer to first hidden layer
    weights1 = weight_variable(NUM_PIXELS, HIDDEN1_UNITS, "weights1")
    biases1 = bias_variable(HIDDEN1_UNITS, "biases1")
    hidden1 = tf.nn.relu(tf.matmul(x, weights1) + biases1, name="hidden1")

    #parameters and predictions from first hidden layer to second hidden layer
    weights2 = weight_variable(HIDDEN1_UNITS, HIDDEN2_UNITS, "weights2")
    biases2 = bias_variable(HIDDEN2_UNITS, "biases2")
    hidden2 = tf.nn.relu(tf.matmul(hidden1, weights2) + biases2, name = "hidden2")

    #parameters and predictions from second hidden layer to output layer
    weights3 = weight_variable(HIDDEN2_UNITS, NUM_CLASSES, "weights3")
    biases3 = bias_variable(NUM_CLASSES, "biases3")
    y = tf.add(tf.matmul(hidden2, weights3), biases3)

    summary_writer = tf.train.SummaryWriter("summaries/single_hidden_layer", graph=tf.get_default_graph())
    summary_writer.close()

    #define loss function
    cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(y, y_))
    
    #define train op
    train_step = tf.train.GradientDescentOptimizer(learning_rate=LEARNING_RATE).minimize(cross_entropy)

    #init op
    sess.run(tf.initialize_all_variables())

    #training routine
    for i in range(TRAIN_STEPS):
        batch_xs, batch_ys = mnist.train.next_batch(BATCH_SIZE)
        _, loss = sess.run([train_step, cross_entropy], feed_dict={x: batch_xs, y_: batch_ys})
        #parameters updated in train step
        if i%200 == 0:
            print("At step %d, loss is %f" % (i, loss))

    #define a prediction to be correct if it agrees with the label:
    correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
    
    #define accuracy by average number of correct predictions over test sample
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    print("Accuracy is %f" % sess.run(accuracy, feed_dict = {x:mnist.test.images, y_: mnist.test.labels}))
    
    #return value for runner function
    return sess.run(accuracy, feed_dict = {x:mnist.test.images, y_: mnist.test.labels})

# %%
class GsRunner():
    """run grid search on hyperparameters for runner function"""
    
    def __init__(
        self,
        train_steps = [100,500,1000,],
        batch_size = [100],
        units1 = [256, 512,],
        units2 = [256, 512,],
        learning_rate = [.1, .3, .5]
                ):
        self.best = {
            "val": 0, 
            "train_steps": None, 
            "batch_size": None, 
            "units1": None, 
            "units2": None, 
            "learning_rate": None
        }
        self.HP = {
            "train_steps": train_steps,
            "batch_size": batch_size,
            "units1": units1,
            "units2": units2,
            "learning_rate": learning_rate,
            
        }

    def update(self, val, **kwargs):
        if val>self.best["val"]:
            self.best["val"] = val
            for k in kwargs.keys():
                self.best[k] = kwargs[k]
            return

    def runner(self):
        for train_steps in self.HP["train_steps"]:
            for batch_size in self.HP["batch_size"]:
                for units1 in self.HP["units1"]:
                    for units2 in self.HP["units2"]:
                        for learning_rate in self.HP["learning_rate"]:
                            kwargs={
                                    "train_steps": train_steps,
                                    "batch_size": batch_size,
                                    "units1": units1,
                                    "units2": units2,
                                    "learning_rate": learning_rate,
                                    
                                }
                            self.update(run(train_steps, batch_size, units1, units2, learning_rate),
                                       **kwargs)
        print("\n\nThe best model trained was :", self.best)
        return self.best

# %%
x = GsRunner(
    train_steps=[1000, 2000, 5000], 
    batch_size=[100], 
    units1=[256,512,1024,], 
    units2=[256,512,1024,], 
    learning_rate=[.1, .2, .5]
            )
x.runner()
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.301068
# At step 200, loss is 0.295217
# At step 400, loss is 0.436825
# At step 600, loss is 0.248036
# At step 800, loss is 0.146709
# Accuracy is 0.947500
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.305903
# At step 200, loss is 0.210042
# At step 400, loss is 0.296103
# At step 600, loss is 0.140414
# At step 800, loss is 0.242736
# Accuracy is 0.962000
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.311038
# At step 200, loss is 0.144835
# At step 400, loss is 0.189375
# At step 600, loss is 0.096443
# At step 800, loss is 0.147415
# Accuracy is 0.970700
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.305480
# At step 200, loss is 0.278438
# At step 400, loss is 0.420948
# At step 600, loss is 0.185137
# At step 800, loss is 0.203300
# Accuracy is 0.951500
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.315636
# At step 200, loss is 0.198372
# At step 400, loss is 0.291208
# At step 600, loss is 0.142014
# At step 800, loss is 0.157623
# Accuracy is 0.961800
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.314537
# At step 200, loss is 0.133250
# At step 400, loss is 0.173222
# At step 600, loss is 0.112097
# At step 800, loss is 0.101297
# Accuracy is 0.970000
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.296094
# At step 200, loss is 0.264191
# At step 400, loss is 0.385226
# At step 600, loss is 0.126282
# At step 800, loss is 0.240799
# Accuracy is 0.952300
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.303960
# At step 200, loss is 0.206896
# At step 400, loss is 0.280305
# At step 600, loss is 0.180047
# At step 800, loss is 0.254197
# Accuracy is 0.965700
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.307887
# At step 200, loss is 0.203718
# At step 400, loss is 0.166119
# At step 600, loss is 0.042388
# At step 800, loss is 0.096205
# Accuracy is 0.968800
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.286421
# At step 200, loss is 0.294939
# At step 400, loss is 0.448031
# At step 600, loss is 0.435818
# At step 800, loss is 0.197647
# Accuracy is 0.947800
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.308084
# At step 200, loss is 0.210373
# At step 400, loss is 0.275716
# At step 600, loss is 0.181049
# At step 800, loss is 0.192692
# Accuracy is 0.963500
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.318838
# At step 200, loss is 0.144866
# At step 400, loss is 0.192882
# At step 600, loss is 0.060846
# At step 800, loss is 0.036575
# Accuracy is 0.966400
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.320346
# At step 200, loss is 0.286164
# At step 400, loss is 0.402960
# At step 600, loss is 0.261046
# At step 800, loss is 0.160503
# Accuracy is 0.951500
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.303736
# At step 200, loss is 0.217638
# At step 400, loss is 0.270969
# At step 600, loss is 0.172752
# At step 800, loss is 0.112383
# Accuracy is 0.964100
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.321969
# At step 200, loss is 0.150622
# At step 400, loss is 0.181757
# At step 600, loss is 0.073566
# At step 800, loss is 0.030479
# Accuracy is 0.961700
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.304833
# At step 200, loss is 0.289921
# At step 400, loss is 0.387437
# At step 600, loss is 0.249736
# At step 800, loss is 0.258134
# Accuracy is 0.949400
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.334255
# At step 200, loss is 0.191175
# At step 400, loss is 0.261919
# At step 600, loss is 0.191924
# At step 800, loss is 0.076553
# Accuracy is 0.967900
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.296729
# At step 200, loss is 0.140885
# At step 400, loss is 0.154260
# At step 600, loss is 0.085433
# At step 800, loss is 0.061238
# Accuracy is 0.969000
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.303255
# At step 200, loss is 0.293505
# At step 400, loss is 0.420788
# At step 600, loss is 0.186414
# At step 800, loss is 0.149294
# Accuracy is 0.952900
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.296450
# At step 200, loss is 0.213504
# At step 400, loss is 0.267092
# At step 600, loss is 0.208358
# At step 800, loss is 0.220816
# Accuracy is 0.965900
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.335351
# At step 200, loss is 0.135031
# At step 400, loss is 0.174931
# At step 600, loss is 0.068761
# At step 800, loss is 0.064084
# Accuracy is 0.974800
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.292796
# At step 200, loss is 0.282536
# At step 400, loss is 0.411040
# At step 600, loss is 0.196792
# At step 800, loss is 0.092752
# Accuracy is 0.951300
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.305355
# At step 200, loss is 0.199432
# At step 400, loss is 0.266614
# At step 600, loss is 0.121991
# At step 800, loss is 0.150957
# Accuracy is 0.965700
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.316035
# At step 200, loss is 0.165335
# At step 400, loss is 0.197045
# At step 600, loss is 0.050772
# At step 800, loss is 0.058601
# Accuracy is 0.964800
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.327285
# At step 200, loss is 0.259078
# At step 400, loss is 0.410053
# At step 600, loss is 0.267217
# At step 800, loss is 0.219979
# Accuracy is 0.952800
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.311212
# At step 200, loss is 0.193585
# At step 400, loss is 0.280751
# At step 600, loss is 0.090234
# At step 800, loss is 0.141979
# Accuracy is 0.968000
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.299469
# At step 200, loss is 0.128234
# At step 400, loss is 0.154022
# At step 600, loss is 0.063978
# At step 800, loss is 0.147284
# Accuracy is 0.972000
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.314174
# At step 200, loss is 0.295190
# At step 400, loss is 0.424715
# At step 600, loss is 0.304779
# At step 800, loss is 0.144981
# At step 1000, loss is 0.163027
# At step 1200, loss is 0.164128
# At step 1400, loss is 0.154724
# At step 1600, loss is 0.174273
# At step 1800, loss is 0.156051
# Accuracy is 0.964300
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.295270
# At step 200, loss is 0.237482
# At step 400, loss is 0.312704
# At step 600, loss is 0.149094
# At step 800, loss is 0.086628
# At step 1000, loss is 0.165184
# At step 1200, loss is 0.082660
# At step 1400, loss is 0.085724
# At step 1600, loss is 0.092507
# At step 1800, loss is 0.040974
# Accuracy is 0.970900
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.320593
# At step 200, loss is 0.145611
# At step 400, loss is 0.199453
# At step 600, loss is 0.210042
# At step 800, loss is 0.073509
# At step 1000, loss is 0.119863
# At step 1200, loss is 0.068308
# At step 1400, loss is 0.032274
# At step 1600, loss is 0.047814
# At step 1800, loss is 0.160686
# Accuracy is 0.970400
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.304198
# At step 200, loss is 0.286618
# At step 400, loss is 0.433716
# At step 600, loss is 0.238662
# At step 800, loss is 0.327829
# At step 1000, loss is 0.200890
# At step 1200, loss is 0.152360
# At step 1400, loss is 0.145303
# At step 1600, loss is 0.175205
# At step 1800, loss is 0.086667
# Accuracy is 0.965000
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.322529
# At step 200, loss is 0.210875
# At step 400, loss is 0.304505
# At step 600, loss is 0.232222
# At step 800, loss is 0.220907
# At step 1000, loss is 0.227860
# At step 1200, loss is 0.071686
# At step 1400, loss is 0.124260
# At step 1600, loss is 0.076680
# At step 1800, loss is 0.164436
# Accuracy is 0.974200
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.322338
# At step 200, loss is 0.150174
# At step 400, loss is 0.229199
# At step 600, loss is 0.123101
# At step 800, loss is 0.169680
# At step 1000, loss is 0.149520
# At step 1200, loss is 0.060765
# At step 1400, loss is 0.065244
# At step 1600, loss is 0.082680
# At step 1800, loss is 0.044176
# Accuracy is 0.973500
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.314668
# At step 200, loss is 0.280417
# At step 400, loss is 0.403064
# At step 600, loss is 0.251602
# At step 800, loss is 0.250948
# At step 1000, loss is 0.046583
# At step 1200, loss is 0.097516
# At step 1400, loss is 0.247971
# At step 1600, loss is 0.054117
# At step 1800, loss is 0.068464
# Accuracy is 0.967600
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.309302
# At step 200, loss is 0.206192
# At step 400, loss is 0.258244
# At step 600, loss is 0.087385
# At step 800, loss is 0.080847
# At step 1000, loss is 0.086451
# At step 1200, loss is 0.116855
# At step 1400, loss is 0.163685
# At step 1600, loss is 0.040796
# At step 1800, loss is 0.086637
# Accuracy is 0.975700
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.317322
# At step 200, loss is 0.149982
# At step 400, loss is 0.169240
# At step 600, loss is 0.206234
# At step 800, loss is 0.076467
# At step 1000, loss is 0.169366
# At step 1200, loss is 0.111215
# At step 1400, loss is 0.031043
# At step 1600, loss is 0.169208
# At step 1800, loss is 0.034005
# Accuracy is 0.972700
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.287542
# At step 200, loss is 0.311526
# At step 400, loss is 0.448313
# At step 600, loss is 0.101377
# At step 800, loss is 0.154258
# At step 1000, loss is 0.222350
# At step 1200, loss is 0.054080
# At step 1400, loss is 0.139959
# At step 1600, loss is 0.104562
# At step 1800, loss is 0.379968
# Accuracy is 0.964500
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.298380
# At step 200, loss is 0.208834
# At step 400, loss is 0.297371
# At step 600, loss is 0.107969
# At step 800, loss is 0.128296
# At step 1000, loss is 0.168057
# At step 1200, loss is 0.057485
# At step 1400, loss is 0.059234
# At step 1600, loss is 0.055381
# At step 1800, loss is 0.034215
# Accuracy is 0.973900
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.310555
# At step 200, loss is 0.136612
# At step 400, loss is 0.153535
# At step 600, loss is 0.093663
# At step 800, loss is 0.069097
# At step 1000, loss is 0.048728
# At step 1200, loss is 0.049946
# At step 1400, loss is 0.053622
# At step 1600, loss is 0.040270
# At step 1800, loss is 0.057958
# Accuracy is 0.978400
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.289003
# At step 200, loss is 0.300708
# At step 400, loss is 0.422693
# At step 600, loss is 0.123497
# At step 800, loss is 0.153998
# At step 1000, loss is 0.120406
# At step 1200, loss is 0.091287
# At step 1400, loss is 0.319712
# At step 1600, loss is 0.203876
# At step 1800, loss is 0.069896
# Accuracy is 0.967300
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.303586
# At step 200, loss is 0.206458
# At step 400, loss is 0.303323
# At step 600, loss is 0.115830
# At step 800, loss is 0.246625
# At step 1000, loss is 0.124278
# At step 1200, loss is 0.069786
# At step 1400, loss is 0.138909
# At step 1600, loss is 0.027972
# At step 1800, loss is 0.057229
# Accuracy is 0.974200
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.291981
# At step 200, loss is 0.157380
# At step 400, loss is 0.133029
# At step 600, loss is 0.102992
# At step 800, loss is 0.089883
# At step 1000, loss is 0.117058
# At step 1200, loss is 0.022722
# At step 1400, loss is 0.057702
# At step 1600, loss is 0.044165
# At step 1800, loss is 0.017540
# Accuracy is 0.974600
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.285885
# At step 200, loss is 0.288733
# At step 400, loss is 0.417468
# At step 600, loss is 0.340631
# At step 800, loss is 0.162772
# At step 1000, loss is 0.265584
# At step 1200, loss is 0.220189
# At step 1400, loss is 0.060162
# At step 1600, loss is 0.080048
# At step 1800, loss is 0.244760
# Accuracy is 0.965800
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.296788
# At step 200, loss is 0.215666
# At step 400, loss is 0.302527
# At step 600, loss is 0.187853
# At step 800, loss is 0.151405
# At step 1000, loss is 0.106030
# At step 1200, loss is 0.243562
# At step 1400, loss is 0.099982
# At step 1600, loss is 0.223057
# At step 1800, loss is 0.030056
# Accuracy is 0.975900
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.347929
# At step 200, loss is 0.155356
# At step 400, loss is 0.218205
# At step 600, loss is 0.082912
# At step 800, loss is 0.147335
# At step 1000, loss is 0.233557
# At step 1200, loss is 0.062802
# At step 1400, loss is 0.094898
# At step 1600, loss is 0.065383
# At step 1800, loss is 0.038729
# Accuracy is 0.977600
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.297096
# At step 200, loss is 0.276343
# At step 400, loss is 0.425252
# At step 600, loss is 0.188152
# At step 800, loss is 0.252749
# At step 1000, loss is 0.140736
# At step 1200, loss is 0.210974
# At step 1400, loss is 0.117906
# At step 1600, loss is 0.091138
# At step 1800, loss is 0.045070
# Accuracy is 0.967000
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.325461
# At step 200, loss is 0.210343
# At step 400, loss is 0.250286
# At step 600, loss is 0.161867
# At step 800, loss is 0.164936
# At step 1000, loss is 0.053840
# At step 1200, loss is 0.046334
# At step 1400, loss is 0.084698
# At step 1600, loss is 0.091849
# At step 1800, loss is 0.053770
# Accuracy is 0.973100
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.310018
# At step 200, loss is 0.126955
# At step 400, loss is 0.166411
# At step 600, loss is 0.123296
# At step 800, loss is 0.117740
# At step 1000, loss is 0.122828
# ...
# At step 3000, loss is 0.013789
# At step 3200, loss is 0.031886
# At step 3400, loss is 0.049675
# At step 3600, loss is 0.026302
# At step 3800, loss is 0.013216
# At step 4000, loss is 0.011443
# At step 4200, loss is 0.043144
# At step 4400, loss is 0.018387
# At step 4600, loss is 0.019274
# At step 4800, loss is 0.030468
# Accuracy is 0.980800
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.316744
# At step 200, loss is 0.134460
# At step 400, loss is 0.157757
# At step 600, loss is 0.140115
# At step 800, loss is 0.151146
# At step 1000, loss is 0.012087
# At step 1200, loss is 0.036487
# At step 1400, loss is 0.057360
# At step 1600, loss is 0.037118
# At step 1800, loss is 0.058342
# At step 2000, loss is 0.037402
# At step 2200, loss is 0.023720
# At step 2400, loss is 0.010225
# At step 2600, loss is 0.022350
# At step 2800, loss is 0.014954
# At step 3000, loss is 0.024367
# At step 3200, loss is 0.028214
# At step 3400, loss is 0.002531
# At step 3600, loss is 0.020069
# At step 3800, loss is 0.001856
# At step 4000, loss is 0.006749
# At step 4200, loss is 0.014160
# At step 4400, loss is 0.008219
# At step 4600, loss is 0.009308
# At step 4800, loss is 0.000276
# Accuracy is 0.983300
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.318279
# At step 200, loss is 0.281016
# At step 400, loss is 0.413751
# At step 600, loss is 0.269389
# At step 800, loss is 0.125289
# At step 1000, loss is 0.147224
# At step 1200, loss is 0.142371
# At step 1400, loss is 0.135949
# At step 1600, loss is 0.115380
# At step 1800, loss is 0.169632
# At step 2000, loss is 0.075082
# At step 2200, loss is 0.044714
# At step 2400, loss is 0.070280
# At step 2600, loss is 0.044777
# At step 2800, loss is 0.033712
# At step 3000, loss is 0.110322
# At step 3200, loss is 0.116836
# At step 3400, loss is 0.043273
# At step 3600, loss is 0.098058
# At step 3800, loss is 0.038531
# At step 4000, loss is 0.031591
# At step 4200, loss is 0.035493
# At step 4400, loss is 0.016218
# At step 4600, loss is 0.029939
# At step 4800, loss is 0.043106
# Accuracy is 0.979300
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.286646
# At step 200, loss is 0.201451
# At step 400, loss is 0.285863
# At step 600, loss is 0.120691
# At step 800, loss is 0.208026
# At step 1000, loss is 0.083154
# At step 1200, loss is 0.010155
# At step 1400, loss is 0.139009
# At step 1600, loss is 0.057346
# At step 1800, loss is 0.109253
# At step 2000, loss is 0.015467
# At step 2200, loss is 0.032094
# At step 2400, loss is 0.042934
# At step 2600, loss is 0.009194
# At step 2800, loss is 0.013699
# At step 3000, loss is 0.014801
# At step 3200, loss is 0.049928
# At step 3400, loss is 0.026751
# At step 3600, loss is 0.010082
# At step 3800, loss is 0.034858
# At step 4000, loss is 0.014400
# At step 4200, loss is 0.005040
# At step 4400, loss is 0.006734
# At step 4600, loss is 0.003607
# At step 4800, loss is 0.001725
# Accuracy is 0.980200
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.302878
# At step 200, loss is 0.147925
# At step 400, loss is 0.148536
# At step 600, loss is 0.106290
# At step 800, loss is 0.068299
# At step 1000, loss is 0.183168
# At step 1200, loss is 0.037220
# At step 1400, loss is 0.049173
# At step 1600, loss is 0.005639
# At step 1800, loss is 0.021440
# At step 2000, loss is 0.041899
# At step 2200, loss is 0.007360
# At step 2400, loss is 0.061991
# At step 2600, loss is 0.041869
# At step 2800, loss is 0.011103
# At step 3000, loss is 0.005304
# At step 3200, loss is 0.003455
# At step 3400, loss is 0.022096
# At step 3600, loss is 0.013344
# At step 3800, loss is 0.027456
# At step 4000, loss is 0.004848
# At step 4200, loss is 0.000826
# At step 4400, loss is 0.001747
# At step 4600, loss is 0.000343
# At step 4800, loss is 0.003035
# Accuracy is 0.983700
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.305023
# At step 200, loss is 0.285144
# At step 400, loss is 0.418282
# At step 600, loss is 0.200273
# At step 800, loss is 0.203325
# At step 1000, loss is 0.148654
# At step 1200, loss is 0.120549
# At step 1400, loss is 0.128674
# At step 1600, loss is 0.164466
# At step 1800, loss is 0.143062
# At step 2000, loss is 0.066231
# At step 2200, loss is 0.039773
# At step 2400, loss is 0.139963
# At step 2600, loss is 0.211298
# At step 2800, loss is 0.071203
# At step 3000, loss is 0.055722
# At step 3200, loss is 0.039862
# At step 3400, loss is 0.053765
# At step 3600, loss is 0.037329
# At step 3800, loss is 0.093367
# At step 4000, loss is 0.073560
# At step 4200, loss is 0.033014
# At step 4400, loss is 0.030353
# At step 4600, loss is 0.027061
# At step 4800, loss is 0.069024
# Accuracy is 0.976500
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.303445
# At step 200, loss is 0.195160
# At step 400, loss is 0.284072
# At step 600, loss is 0.197761
# At step 800, loss is 0.179475
# At step 1000, loss is 0.134696
# At step 1200, loss is 0.102825
# At step 1400, loss is 0.089685
# At step 1600, loss is 0.115041
# At step 1800, loss is 0.171279
# At step 2000, loss is 0.038576
# At step 2200, loss is 0.060355
# At step 2400, loss is 0.007666
# At step 2600, loss is 0.037396
# At step 2800, loss is 0.020805
# At step 3000, loss is 0.058130
# At step 3200, loss is 0.027830
# At step 3400, loss is 0.037369
# At step 3600, loss is 0.022922
# At step 3800, loss is 0.019155
# At step 4000, loss is 0.031024
# At step 4200, loss is 0.008774
# At step 4400, loss is 0.015920
# At step 4600, loss is 0.048827
# At step 4800, loss is 0.010846
# Accuracy is 0.982300
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.295277
# At step 200, loss is 0.135628
# At step 400, loss is 0.151360
# At step 600, loss is 0.137147
# At step 800, loss is 0.083698
# At step 1000, loss is 0.025407
# At step 1200, loss is 0.043042
# At step 1400, loss is 0.108665
# At step 1600, loss is 0.075856
# At step 1800, loss is 0.053490
# At step 2000, loss is 0.024376
# At step 2200, loss is 0.026302
# At step 2400, loss is 0.023760
# At step 2600, loss is 0.028213
# At step 2800, loss is 0.006948
# At step 3000, loss is 0.006276
# At step 3200, loss is 0.006665
# At step 3400, loss is 0.003879
# At step 3600, loss is 0.018785
# At step 3800, loss is 0.008104
# At step 4000, loss is 0.011346
# At step 4200, loss is 0.003874
# At step 4400, loss is 0.002175
# At step 4600, loss is 0.000392
# At step 4800, loss is 0.001198
# Accuracy is 0.984000
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.307094
# At step 200, loss is 0.282061
# At step 400, loss is 0.409704
# At step 600, loss is 0.313028
# At step 800, loss is 0.115163
# At step 1000, loss is 0.278447
# At step 1200, loss is 0.169306
# At step 1400, loss is 0.155783
# At step 1600, loss is 0.102910
# At step 1800, loss is 0.176348
# At step 2000, loss is 0.067771
# At step 2200, loss is 0.130263
# At step 2400, loss is 0.146237
# At step 2600, loss is 0.018657
# At step 2800, loss is 0.044163
# At step 3000, loss is 0.090188
# At step 3200, loss is 0.094000
# At step 3400, loss is 0.061261
# At step 3600, loss is 0.027150
# At step 3800, loss is 0.021783
# At step 4000, loss is 0.085229
# At step 4200, loss is 0.037928
# At step 4400, loss is 0.015323
# At step 4600, loss is 0.033846
# At step 4800, loss is 0.128234
# Accuracy is 0.975100
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.309890
# At step 200, loss is 0.205435
# At step 400, loss is 0.269607
# At step 600, loss is 0.131565
# At step 800, loss is 0.059482
# At step 1000, loss is 0.074258
# At step 1200, loss is 0.103883
# At step 1400, loss is 0.059147
# At step 1600, loss is 0.044229
# At step 1800, loss is 0.056290
# At step 2000, loss is 0.026682
# At step 2200, loss is 0.048187
# At step 2400, loss is 0.026966
# At step 2600, loss is 0.029675
# At step 2800, loss is 0.181883
# At step 3000, loss is 0.006912
# At step 3200, loss is 0.027791
# At step 3400, loss is 0.008746
# At step 3600, loss is 0.022670
# At step 3800, loss is 0.015832
# At step 4000, loss is 0.018254
# At step 4200, loss is 0.020052
# At step 4400, loss is 0.036293
# At step 4600, loss is 0.009805
# At step 4800, loss is 0.012080
# Accuracy is 0.982500
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:42 in run.: SummaryWriter.__init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# WARNING:tensorflow:From <ipython-input-14-a382a5a38f04>:52 in run.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# At step 0, loss is 2.296230
# At step 200, loss is 0.127554
# At step 400, loss is 0.142936
# At step 600, loss is 0.087481
# At step 800, loss is 0.084244
# At step 1000, loss is 0.110211
# At step 1200, loss is 0.027147
# At step 1400, loss is 0.034300
# At step 1600, loss is 0.030980
# At step 1800, loss is 0.011268
# At step 2000, loss is 0.061780
# At step 2200, loss is 0.046571
# At step 2400, loss is 0.010788
# At step 2600, loss is 0.054444
# At step 2800, loss is 0.010538
# At step 3000, loss is 0.009054
# At step 3200, loss is 0.023979
# At step 3400, loss is 0.005132
# At step 3600, loss is 0.009118
# At step 3800, loss is 0.000560
# At step 4000, loss is 0.001561
# At step 4200, loss is 0.000636
# At step 4400, loss is 0.001507
# At step 4600, loss is 0.001644
# At step 4800, loss is 0.002197
# Accuracy is 0.983200
# {'batch_size': 100,
#  'learning_rate': 0.5,
#  'train_steps': 5000,
#  'units1': 512,
#  'units2': 512,
#  'val': 0.98430002}
